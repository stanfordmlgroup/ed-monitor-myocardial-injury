# %% [markdown]
# # Transformer Model Training
#
# Training the monitoring models using the smaller dataset built for the 12-lead data (since there are invalid 12-lead samples)

# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
from edm.jobs.rf_job import RandomForestJob
from edm.jobs.lr_job import LogisticRegressionJob
from edm.jobs.mlp_job import MlpJob

pd.set_option('display.max_columns', None)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 15sec-500hz-1norm-1wpp

# %% [markdown]
# ### 64

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-64/waveform-only/12-lead-subset",
    save_model=False,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5054.71it/s]
# Produced embedding for df_train_x with shape = (7246, 66)
# 1283it [00:00, 5307.66it/s]
# Produced embedding for df_val_x with shape = (1283, 66)
# 1278it [00:00, 5421.91it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Produced embedding for df_test_x with shape = (1278, 66)
# Starting model training...
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.73, AUC COV=0.0, 95% CI=[0.711, 0.75]; AUPRC=0.224, 95% CI=N/A
# TRAIN AUROC = (0.7301618050259651, 0.22369930973155244) AUPRC = 0.22369930973155244 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.691, AUC COV=0.001, 95% CI=[0.646, 0.737]; AUPRC=0.235, 95% CI=N/A
# VAL AUROC = (0.6914246213477183, 0.23518969708194482) AUPRC = 0.23518969708194482 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 4/10000 [00:00<05:05, 32.70it/s]
# [DeLong] AUC=0.71, AUC COV=0.001, 95% CI=[0.666, 0.754]; AUPRC=0.24, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:09<00:00, 32.35it/s]
# [Bootstrap] AUC=0.71, 95% CI=[0.664, 0.753]; AUPRC=0.24, 95% CI=[0.183, 0.314]
# TEST AUROC = (0.7098047637394913, 0.24026189017330055) AUPRC = 0.24026189017330055 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============

# %% [markdown]
# ### 256

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-256/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-256/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-256/waveform-only/12-lead-subset",
    save_model=False,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 4873.06it/s]
# Produced embedding for df_train_x with shape = (7246, 258)
# 1283it [00:00, 5067.11it/s]
# Produced embedding for df_val_x with shape = (1283, 258)
# 1278it [00:00, 5194.66it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Produced embedding for df_test_x with shape = (1278, 258)
# Starting model training...
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 49.5 K
# --------------------------------------------
# 49.5 K    Trainable params
# 0         Non-trainable params
# 49.5 K    Total params
# 0.198     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.724, AUC COV=0.0, 95% CI=[0.704, 0.743]; AUPRC=0.212, 95% CI=N/A
# TRAIN AUROC = (0.7235158604786289, 0.21203615060860131) AUPRC = 0.21203615060860131 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.695, AUC COV=0.001, 95% CI=[0.65, 0.741]; AUPRC=0.225, 95% CI=N/A
# VAL AUROC = (0.6951957141622742, 0.22475271535255154) AUPRC = 0.22475271535255154 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 4/10000 [00:00<05:04, 32.85it/s]
# [DeLong] AUC=0.699, AUC COV=0.001, 95% CI=[0.654, 0.745]; AUPRC=0.223, 95% CI=N/A
# 100%|██████████| 10000/10000 [04:56<00:00, 33.74it/s]
# [Bootstrap] AUC=0.699, 95% CI=[0.652, 0.743]; AUPRC=0.223, 95% CI=[0.171, 0.291]
# TEST AUROC = (0.6993197364847366, 0.22329029141587975) AUPRC = 0.22329029141587975 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============

# %% [markdown]
# # 15sec-500hz-1norm-10wpp

# %% [markdown]
# ## Waveform Only

# %% [markdown]
# ### MLP

# %% [markdown]
# #### 64

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only/12-lead-subset",
    save_model=False,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5242.05it/s]
# Produced embedding for df_train_x with shape = (7246, 66)
# 1283it [00:00, 5454.62it/s]
# Produced embedding for df_val_x with shape = (1283, 66)
# 1278it [00:00, 5354.15it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# Produced embedding for df_test_x with shape = (1278, 66)
# Starting model training...
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.739, AUC COV=0.0, 95% CI=[0.72, 0.758]; AUPRC=0.226, 95% CI=N/A
# TRAIN AUROC = (0.7387243753858446, 0.22601425240475698) AUPRC = 0.22601425240475698 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.731, AUC COV=0.0, 95% CI=[0.688, 0.774]; AUPRC=0.267, 95% CI=N/A
# VAL AUROC = (0.7310303539025564, 0.2674260470006139) AUPRC = 0.2674260470006139 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 4/10000 [00:00<05:06, 32.61it/s]
# [DeLong] AUC=0.722, AUC COV=0.0, 95% CI=[0.679, 0.765]; AUPRC=0.26, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:08<00:00, 32.42it/s]
# [Bootstrap] AUC=0.722, 95% CI=[0.676, 0.764]; AUPRC=0.26, 95% CI=[0.196, 0.331]
# TEST AUROC = (0.7219636055861194, 0.2598043023500816) AUPRC = 0.2598043023500816 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============

# %% [markdown]
# #### 256

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-256/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-256/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-256/waveform-only/12-lead-subset",
    save_model=False,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5069.60it/s]
# Produced embedding for df_train_x with shape = (7246, 258)
# 1283it [00:00, 5318.17it/s]
# Produced embedding for df_val_x with shape = (1283, 258)
# 1278it [00:00, 5222.39it/s]
# Global seed set to 1234
# Produced embedding for df_test_x with shape = (1278, 258)
# Starting model training...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 49.5 K
# --------------------------------------------
# 49.5 K    Trainable params
# 0         Non-trainable params
# 49.5 K    Total params
# 0.198     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.736, AUC COV=0.0, 95% CI=[0.717, 0.756]; AUPRC=0.226, 95% CI=N/A
# TRAIN AUROC = (0.7363146629988744, 0.2259043925198439) AUPRC = 0.2259043925198439 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.73, AUC COV=0.0, 95% CI=[0.688, 0.773]; AUPRC=0.258, 95% CI=N/A
# VAL AUROC = (0.7304933897865722, 0.25843821690660806) AUPRC = 0.25843821690660806 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 3/10000 [00:00<06:39, 25.02it/s]
# [DeLong] AUC=0.722, AUC COV=0.001, 95% CI=[0.678, 0.767]; AUPRC=0.252, 95% CI=N/A
# 100%|██████████| 10000/10000 [04:48<00:00, 34.63it/s]
# [Bootstrap] AUC=0.722, 95% CI=[0.676, 0.765]; AUPRC=0.252, 95% CI=[0.193, 0.325]
# TEST AUROC = (0.7224246941340695, 0.2518097075942714) AUPRC = 0.2518097075942714 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============

# %% [markdown]
# ## 15sec-500hz-1norm-1wpp (Waveform + Age + Sex + Vital Signs)

# %% [markdown]
# #### 64

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital/12-lead-subset",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 4083.30it/s]
# Produced embedding for df_train_x with shape = (7246, 74)
# 1283it [00:00, 4200.81it/s]
# Produced embedding for df_val_x with shape = (1283, 74)
# 1278it [00:00, 4043.51it/s]
# Produced embedding for df_test_x with shape = (1278, 74)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.0 K
# --------------------------------------------
# 26.0 K    Trainable params
# 0         Non-trainable params
# 26.0 K    Total params
# 0.104     Total estimated model params size (MB)
# Cleaned columns with additional_cols=['Age', 'Gender', 'SpO2', 'RR', 'HR', 'Temp', 'SBP', 'DBP'] impute=True normalize=True
# Starting model training...
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.765, AUC COV=0.0, 95% CI=[0.747, 0.784]; AUPRC=0.279, 95% CI=N/A
# TRAIN AUROC = (0.7651196571885099, 0.27946356875480344) AUPRC = 0.27946356875480344 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.749, AUC COV=0.0, 95% CI=[0.708, 0.789]; AUPRC=0.308, 95% CI=N/A
# VAL AUROC = (0.748676105714039, 0.3075314320873938) AUPRC = 0.3075314320873938 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 4/10000 [00:00<05:06, 32.63it/s]
# [DeLong] AUC=0.759, AUC COV=0.0, 95% CI=[0.718, 0.799]; AUPRC=0.303, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:09<00:00, 32.31it/s]
# [Bootstrap] AUC=0.759, 95% CI=[0.717, 0.798]; AUPRC=0.303, 95% CI=[0.234, 0.387]
# TEST AUROC = (0.7587054149481117, 0.30292999147528005) AUPRC = 0.30292999147528005 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============

# %% [markdown]
# ## 15sec-500hz-1norm-1wpp (Waveform + Age + Sex + Vital Signs + Risk)

# %% [markdown]
# #### 64

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital-risk/12-lead-subset",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP", "Athero", "HTN", "HLD", "DM", "Obese", "Smoking"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:02, 3501.85it/s]
# Produced embedding for df_train_x with shape = (7246, 80)
# 1283it [00:00, 3633.42it/s]
# Produced embedding for df_val_x with shape = (1283, 80)
# 1278it [00:00, 3612.03it/s]
# Produced embedding for df_test_x with shape = (1278, 80)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.8 K
# --------------------------------------------
# 26.8 K    Trainable params
# 0         Non-trainable params
# 26.8 K    Total params
# 0.107     Total estimated model params size (MB)
# Cleaned columns with additional_cols=['Age', 'Gender', 'SpO2', 'RR', 'HR', 'Temp', 'SBP', 'DBP', 'Athero', 'HTN', 'HLD', 'DM', 'Obese', 'Smoking'] impute=True normalize=True
# Starting model training...
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 1234
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ------------------------------------
#
#
# ============= TRAIN ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.757, AUC COV=0.0, 95% CI=[0.738, 0.775]; AUPRC=0.264, 95% CI=N/A
# TRAIN AUROC = (0.7566086084177651, 0.26367117771159354) AUPRC = 0.26367117771159354 using data size 7246 with 670 ACS
# Best Checkpoint =
#
#
# ============= VAL ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [DeLong] AUC=0.738, AUC COV=0.0, 95% CI=[0.696, 0.779]; AUPRC=0.287, 95% CI=N/A
# VAL AUROC = (0.7376467393316957, 0.28680845035109925) AUPRC = 0.28680845035109925 using data size 1283 with 142 pos
#
#
# ============= TEST ROC CURVE ===============
# Testing: 0it [00:00, ?it/s]
#   0%|          | 4/10000 [00:00<05:05, 32.71it/s]
# [DeLong] AUC=0.76, AUC COV=0.0, 95% CI=[0.719, 0.801]; AUPRC=0.314, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:07<00:00, 32.47it/s]
# [Bootstrap] AUC=0.76, 95% CI=[0.717, 0.799]; AUPRC=0.314, 95% CI=[0.241, 0.395]
# TEST AUROC = (0.7600255177771741, 0.3137832721304784) AUPRC = 0.3137832721304784 using data size 1278 with 139 pos
#
#
# ============= TRAIN/VAL LOSS CURVE ===============
