# %% [markdown]
# # Transformer Model Training

# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve, auc, roc_auc_score, precision_recall_curve
from edm.jobs.mlp_job import MlpJob
from edm.utils.measures import perf_measure, calculate_output_statistics, get_bootstrap_metrics

pd.set_option('display.max_columns', None)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 15sec-500hz-1norm-1wpp

# %% [markdown]
# ## Waveform Only

# %% [markdown]
# ### MLP

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-64/waveform-only",
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 5561.72it/s]
# Produced embedding for df_train_x with shape = (8162, 66)
# 1356it [00:00, 5815.33it/s]
# Produced embedding for df_val_x with shape = (1356, 66)
# 1356it [00:00, 5844.79it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# ...

# %% [markdown]
# ### MLP (using 12-lead subset)

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-64/waveform-only-12leadsubset",
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5579.94it/s]
# Produced embedding for df_train_x with shape = (7246, 66)
# 1283it [00:00, 5808.85it/s]
# Produced embedding for df_val_x with shape = (1283, 66)
# 1278it [00:00, 5843.50it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# ...

# %% [markdown]
# ## Waveform + Age + Sex + Vital Signs

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-64/waveform-demo-vital",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 4352.58it/s]
# Produced embedding for df_train_x with shape = (8162, 74)
# 1356it [00:00, 4492.59it/s]
# Produced embedding for df_val_x with shape = (1356, 74)
# 1356it [00:00, 4531.05it/s]
# Produced embedding for df_test_x with shape = (1356, 74)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.0 K
# --------------------------------------------
# 26.0 K    Trainable params
# 0         Non-trainable params
# 26.0 K    Total params
# ...

# %% [markdown]
# ## Waveform + Age + Sex + Vital Signs + Risk

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-1wpp/II/final-transformer-64/waveform-demo-vital-risk",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP", "Athero", "HTN", "HLD", "DM", "Obese", "Smoking"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:02, 3736.75it/s]
# Produced embedding for df_train_x with shape = (8162, 80)
# 1356it [00:00, 3829.79it/s]
# Produced embedding for df_val_x with shape = (1356, 80)
# 1356it [00:00, 3885.15it/s]
# Produced embedding for df_test_x with shape = (1356, 80)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.8 K
# --------------------------------------------
# 26.8 K    Trainable params
# 0         Non-trainable params
# 26.8 K    Total params
# ...

# %% [markdown]
# # 15sec-500hz-1norm-10wpp

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Hyperparameter tuning
#
best_auroc_val = 0
best_combination = []
for layers in [2, 3, 4]:
    for inner_dim in [32, 64, 128]:
        for dropout in [0, 0.3, 0.5]:
            print(f"RUNNING layers={layers}, inner_dim={inner_dim}, dropout={dropout}")
            mlp = MlpJob(
                df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
                df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
                df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
                summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
                embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
                save_model=False,
                run_bootstrap_ci=False,
                verbose=0
            )

            auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                                         learning_rate=0.001, 
                                                         dropout_rate=dropout, 
                                                         num_inner_layers=layers, 
                                                         epochs=10, 
                                                         inner_dim=inner_dim)
            print(f"> auroc_train={auroc_train}, auroc_val={auroc_val}, auroc_test={auroc_test}")
            if auroc_val[0] > best_auroc_val:
                best_auroc_val = auroc_val[0]
                best_combination = [layers, inner_dim, dropout]

print("===")
print(f"BEST COMBINATION = {best_combination}")
# Out:
# RUNNING layers=2, inner_dim=32, dropout=0
# 8162it [00:01, 5235.63it/s]
# 1356it [00:00, 5529.13it/s]
# 1356it [00:00, 5512.25it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Global seed set to 1234
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   "`trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6."
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:679: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
# ...

# %% [markdown]
# ## Waveform Only

# %% [markdown]
# ### MLP

# %%
# With tuned hyperparameters
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only",
    save_model=True,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 5228.39it/s]
# Produced embedding for df_train_x with shape = (8162, 66)
# 1356it [00:00, 5513.69it/s]
# Produced embedding for df_val_x with shape = (1356, 66)
# 1356it [00:00, 5528.81it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# ...

# %%
# Get bootstrap again, but this time with a fixed seed
# 

def get_ci(bootstrap_aucs, bootstrap_auprcs, y_actual, y_pred, alpha=0.95):
    p = ((1.0-alpha)/2.0) * 100
    lower = max(0.0, np.percentile(bootstrap_aucs, p))
    p = (alpha+((1.0-alpha)/2.0)) * 100
    upper = min(1.0, np.percentile(bootstrap_aucs, p))

    auc_ci = [round(lower, 3), round(upper, 3)]

    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_actual, y_pred)
    auc_keras = auc(fpr_keras, tpr_keras)

    p = ((1.0-alpha)/2.0) * 100
    lower = max(0.0, np.percentile(bootstrap_auprcs, p))
    p = (alpha+((1.0-alpha)/2.0)) * 100
    upper = min(1.0, np.percentile(bootstrap_auprcs, p))

    auprc_ci = [round(lower, 3), round(upper, 3)]

    precision, recall, _ = precision_recall_curve(y_actual, y_pred)
    auprc = auc(recall, precision)

    print(f"[Bootstrap] AUC={round(auc_keras, 3)}, 95% CI={auc_ci}; AUPRC={round(auprc, 3)}, 95% CI={auprc_ci}")

df_waveform = pd.read_csv(f"/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only/test.csv")
waveforms_aucs, waveforms_auprcs = get_bootstrap_metrics(df_waveform["preds"].tolist(), df_waveform["actual"].tolist())
get_ci(waveforms_aucs, waveforms_auprcs, df_waveform["actual"].tolist(), df_waveform["preds"].tolist())
# Out:
# 100%|██████████| 10000/10000 [05:17<00:00, 31.49it/s]
# [Bootstrap] AUC=0.726, 95% CI=[0.684, 0.766]; AUPRC=0.265, 95% CI=[0.204, 0.336]

# %% [markdown]
# #### Save Best Models

# %%
# Save model somewhere more permanent
# !cp /deep/u/tomjin/aihc-win21-ed-monitor/notebooks/v9/lightning_logs/version_216/checkpoints/epoch=45-step=2943.ckpt /deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only

# %%
# !ls -l /deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only

# %%
# Validate model

mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt", # Must be the original files
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt", # Must be the original files
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt", # File that you actually want to test with
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path=None,
    verbose=1
)

final_patient_ids, final_preds, final_y = mlp.test(
    "/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only/epoch=45-step=2943.ckpt",
     batch_size=128, 
     dropout_rate=0.3, 
     num_inner_layers=3,
     inner_dim=128
)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 5295.55it/s]
# Produced embedding for df_train_x with shape = (8162, 66)
# 1356it [00:00, 5418.57it/s]
# Produced embedding for df_val_x with shape = (1356, 66)
# 1356it [00:00, 5442.01it/s]
# Produced embedding for df_test_x with shape = (1356, 66)
# Starting model testing...
# 100%|██████████| 11/11 [00:01<00:00,  5.80it/s]
# ============= TEST ROC CURVE ===============
#   0%|          | 4/10000 [00:00<05:18, 31.43it/s]
# [DeLong] AUC=0.735, AUC COV=0.0, 95% CI=[0.693, 0.777]; AUPRC=0.268, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:17<00:00, 31.48it/s]
# [Bootstrap] AUC=0.735, 95% CI=[0.692, 0.776]; AUPRC=0.268, 95% CI=[0.211, 0.334]
# ...

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(final_y, final_preds)
optimal_idx = np.argmax(tpr_keras - fpr_keras)
optimal_threshold = thresholds_keras[optimal_idx]
print(f"optimal_threshold={optimal_threshold}")
# Out:
# optimal_threshold=0.08275610953569412

# %%
sum(np.array(final_preds >= optimal_threshold, dtype=np.int) == np.array(final_y)) / len(final_y)
# Out:
# 0.6497050147492626

# %%
# Test model

mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt", # Must be the original files
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt", # Must be the original files
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt", # File that you actually want to test with
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only",
    verbose=1
)

final_patient_ids, final_preds, final_y = mlp.test(
    "/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only/epoch=45-step=2943.ckpt",
     batch_size=128, 
     dropout_rate=0.3, 
     num_inner_layers=3,
     inner_dim=128
)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 5539.06it/s]
# Produced embedding for df_train_x with shape = (8162, 66)
# 1356it [00:00, 5768.70it/s]
# Produced embedding for df_val_x with shape = (1356, 66)
# 1356it [00:00, 5753.42it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# Produced embedding for df_test_x with shape = (1356, 66)
# Starting model testing...
# 100%|██████████| 11/11 [00:01<00:00, 10.57it/s]
# ============= TEST ROC CURVE ===============
#   0%|          | 4/10000 [00:00<05:13, 31.90it/s]
# [DeLong] AUC=0.726, AUC COV=0.0, 95% CI=[0.685, 0.767]; AUPRC=0.265, 95% CI=N/A
# 100%|██████████| 10000/10000 [05:15<00:00, 31.67it/s]
# [Bootstrap] AUC=0.726, 95% CI=[0.684, 0.766]; AUPRC=0.265, 95% CI=[0.204, 0.336]
# ...

# %%
final_patient_ids = set(final_patient_ids)

# %%
print(f"Overall Accuracy = {100*sum(np.array(final_preds >= optimal_threshold, dtype=np.int) == np.array(final_y)) / len(final_y)}%")
# Out:
# Overall Accuracy = 65.04424778761062%

# %%
# Find the accuracy on only the subset of samples which the clinicians did their manual analysis on

df_clinician = pd.read_csv("/deep/group/ed-monitor/experiments-v8/prna-128-15/fold_8/outfiles/test.csv")
matched_file="/deep/u/tomjin/aihc-win21-ed-monitor/scripts/v8/cohort_matched_output_v8.csv"
df_matched = pd.read_csv(matched_file, delimiter=",")[["CSN", "CaseID", "Age", "Gender", "SpO2", "SBP", "DBP", "RR", "HR", "Temp"]]
df_clinician = pd.merge(df_clinician, df_matched, how="left", left_on="patient_id", right_on="CaseID")
clinician_pts = set(df_clinician["CSN"].tolist())
len(clinician_pts)
# Out:
# 200

# %%
clinician_actuals = []
clinician_preds = []
for i, p in enumerate(final_patient_ids):
    if p in clinician_pts:
        clinician_actuals.append(final_y[i])
        clinician_preds.append(final_preds[i])
print(f"clinician_actuals={len(clinician_actuals)}")
print(f"clinician_preds={len(clinician_preds)}")
# Out:
# clinician_actuals=200
# clinician_preds=200

# %%
print(f"Overall Accuracy = {100*sum(np.array(clinician_preds >= optimal_threshold, dtype=np.int) == np.array(clinician_actuals)) / len(clinician_actuals)}%")
# Out:
# Overall Accuracy = 65.5%

# %% [markdown]
# ### MLP (using 12-lead subset)

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only-12lead",
    save_model=True,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5319.09it/s]
# Produced embedding for df_train_x with shape = (7246, 66)
# 1283it [00:00, 5493.20it/s]
# Produced embedding for df_val_x with shape = (1283, 66)
# 1278it [00:00, 5364.55it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# ...

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-only-12lead",
    save_model=True,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 5576.68it/s]
# Produced embedding for df_train_x with shape = (7246, 66)
# 1283it [00:00, 5830.74it/s]
# Produced embedding for df_val_x with shape = (1283, 66)
# 1278it [00:00, 5848.39it/s]
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 25.0 K
# --------------------------------------------
# 25.0 K    Trainable params
# 0         Non-trainable params
# 25.0 K    Total params
# 0.100     Total estimated model params size (MB)
# ...

# %% [markdown]
# ## Waveform + Age + Sex + Vital Signs

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 4326.23it/s]
# Produced embedding for df_train_x with shape = (8162, 74)
# 1356it [00:00, 4533.02it/s]
# Produced embedding for df_val_x with shape = (1356, 74)
# 1356it [00:00, 4471.68it/s]
# Produced embedding for df_test_x with shape = (1356, 74)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.0 K
# --------------------------------------------
# 26.0 K    Trainable params
# 0         Non-trainable params
# 26.0 K    Total params
# ...

# %%
# Rerun to save model...

mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital-run-2",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP"],
    ordinal_cols=["Gender"],
    save_model=True,
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:01, 4351.26it/s]
# Produced embedding for df_train_x with shape = (8162, 74)
# 1356it [00:00, 4534.34it/s]
# Produced embedding for df_val_x with shape = (1356, 74)
# 1356it [00:00, 4426.43it/s]
# Produced embedding for df_test_x with shape = (1356, 74)
# Global seed set to 1234
# /deep/u/tomjin/miniconda3/envs/ml/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=1)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
# ...

# %% [markdown]
# ## Waveform + Age + Sex + Vital Signs + Risk

# %% [markdown]
# ### MLP

# %%
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital-risk",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP", "Athero", "HTN", "HLD", "DM", "Obese", "Smoking"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (8162, 79), pos = (757, 79), neg = (7405, 79)
# Read df_val with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# Read df_test with shape = (1356, 79), pos = (150, 79), neg = (1206, 79)
# 8162it [00:02, 3739.94it/s]
# Produced embedding for df_train_x with shape = (8162, 80)
# 1356it [00:00, 3872.58it/s]
# Produced embedding for df_val_x with shape = (1356, 80)
# 1356it [00:00, 3871.31it/s]
# Produced embedding for df_test_x with shape = (1356, 80)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.8 K
# --------------------------------------------
# 26.8 K    Trainable params
# 0         Non-trainable params
# 26.8 K    Total params
# ...

# %% [markdown]
# ### MLP (Using 12-lead Subset)

# %%
# Test Bootstrap
mlp = MlpJob(
    df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.train.txt",
    df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.val.txt",
    df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.12lead.test.txt",
    summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings_summary.csv",
    embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-10wpp/II/transformer-64/embeddings.dat.npy",
    save_predictions_path="/deep/group/ed-monitor/patient_data_v9/predictions/15sec-500hz-1norm-10wpp/II/final-transformer-64/waveform-demo-vital-risk-12lead",
    additional_cols=["Age", "Gender", "SpO2", "RR", "HR", "Temp", "SBP", "DBP", "Athero", "HTN", "HLD", "DM", "Obese", "Smoking"],
    ordinal_cols=["Gender"],
    verbose=1
)

auroc_train, auroc_val, auroc_test = mlp.run(batch_size=128, 
                                             learning_rate=0.0001, 
                                             dropout_rate=0.3, 
                                             num_inner_layers=3, 
                                             epochs=100, 
                                             inner_dim=128,
                                             patience=10)
# Out:
# Read df_train with shape = (7246, 79), pos = (670, 79), neg = (6576, 79)
# Read df_val with shape = (1283, 79), pos = (142, 79), neg = (1141, 79)
# Read df_test with shape = (1278, 79), pos = (139, 79), neg = (1139, 79)
# 7246it [00:01, 3749.63it/s]
# Produced embedding for df_train_x with shape = (7246, 80)
# 1283it [00:00, 3848.85it/s]
# Produced embedding for df_val_x with shape = (1283, 80)
# 1278it [00:00, 3888.35it/s]
# Produced embedding for df_test_x with shape = (1278, 80)
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | loss  | BCEWithLogitsLoss | 0
# 1 | model | MLP               | 26.8 K
# --------------------------------------------
# 26.8 K    Trainable params
# 0         Non-trainable params
# 26.8 K    Total params
# ...

# %% [markdown]
# ## Non-Pretrained Transformer

# %% [markdown]
# ```
# python -u /deep/u/tomjin/ed-monitor-data/processing/train_transformer_from_scratch.py
#
# #!/usr/bin/env python
#
# import os
# import sys
# import numpy as np
# import pandas as pd
# from sklearn.metrics import roc_curve, auc
# from edm.jobs.transformer_job import TransformerJob
#
# tj = TransformerJob(
#     df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
#     df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
#     df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
#     summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/summary.csv",
#     embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/waveforms.dat.npy",
#     save_predictions_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64-scratch",
#     run_bootstrap_ci=False,
#     save_model=True
# )
#
# auroc_train, auroc_val, auroc_test = tj.run(epochs=100, patience=10)
# print(auroc_train, auroc_val, auroc_test)
# ```

# %% [markdown]
# ```
# python -u /deep/u/tomjin/ed-monitor-data/processing/test_transformer_from_scratch.py
#
# import os
# import sys
# import numpy as np
# import pickle
# import pandas as pd
# from sklearn.metrics import roc_curve, auc
# from edm.jobs.transformer_job import TransformerJob
#
# tj = TransformerJob(
#     df_train_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.train.txt",
#     df_val_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.val.txt",
#     df_test_path="/deep/group/ed-monitor/patient_data_v9/consolidated.filtered.test.txt",
#     summary_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/summary.csv",
#     embeddings_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/waveforms.dat.npy",
#     save_predictions_path="/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64-scratch-test",
#     run_bootstrap_ci=True,
#     verbose=0
# )
#
# final_patient_ids, final_preds, final_y = tj.test("/deep/u/tomjin/ed-monitor-data/submissions/checkpoints/epoch=8-step=575.ckpt")
#
# a = {
#     "final_patient_ids": final_patient_ids,
#     "final_preds": final_preds,
#     "final_y": final_y
# }
#
# with open('/deep/group/ed-monitor/patient_data_v9/waveforms/15sec-500hz-1norm-1wpp/II/transformer-64-scratch/test_output.pkl', 'wb') as handle:
#     pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)
# ```

# %%
# !tail -3 "/deep/u/tomjin/ed-monitor-data/submissions/transformer-scratch-3471085.out"
# Out:
# [Bootstrap] AUC=0.659, 95% CI=[0.611, 0.706]; AUPRC=0.206, 95% CI=[0.16, 0.267]
# TEST AUROC = (0.6590049751243781, 0.20553538503639118) AUPRC = 0.20553538503639118 using data size 1356 with 150 pos
# Done
